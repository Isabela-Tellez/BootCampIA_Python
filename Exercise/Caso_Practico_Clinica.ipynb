# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabela-Tellez/BootCampIA_Python/blob/main/Exercise/Caso_Practico_Clinica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Paciente_1 = {
    "edad" : 20,
    "frecuencia_cardiaca" : 68,
    "temperatura" : 41.3,
    "tiene_sintomas_infecciosos" : True,
    "esta_vacunado" : True,
    "es_emergencia_critica" : True
}

Paciente_2 = {
    "edad" : 80,
    "frecuencia_cardiaca" : 101,
    "temperatura" : 39.5,
    "tiene_sintomas_infecciosos" : False,
    "esta_vacunado" : True,
    "es_emergencia_critica" : False
}

Paciente_3 = {
    "edad" : 11,
    "frecuencia_cardiaca" : 90,
    "temperatura" : 38.4,
    "tiene_sintomas_infecciosos" : True,
    "esta_vacunado" : False,
    "es_emergencia_critica" : False
}

Paciente_4 = {
    "edad" : 20,
    "frecuencia_cardiaca" : 72,
    "temperatura" : 37.5,
    "tiene_sintomas_infecciosos" : False,
    "esta_vacunado" : True,
    "es_emergencia_critica" : False
}
#Paciente 1
if Paciente_1["es_emergencia_critica"] or Paciente_1["temperatura"] > 41:
   print("Paciente:", "Paciente_1", "Prioridad Roja (Inmediata)")

elif Paciente_1["temperatura"] >= 39 and Paciente_1["frecuencia_cardiaca"] > 100:
   print("Paciente:", "Paciente_1","Prioridad Naranja (Urgente)")

elif Paciente_1["edad"] < 12 or Paciente_1["edad"] > 65:
   print("Paciente:", "Paciente_1","Prioridad Amarilla (Estandar)")

else:
   print("Paciente:", "Paciente_1","Prioridad Verde (No urgente)")

#Protocolo de aislamiento Paciente 1
if Paciente_1["tiene_sintomas_infecciosos"] and not Paciente_1["esta_vacunado"]:
    destino = "Box de Aislamiento"
else:
    destino = "Sala de Espera General"
print(destino, "\n")


#Paciente 2
if Paciente_2["es_emergencia_critica"] or Paciente_2["temperatura"] > 41:
   print("Prioridad Roja (Inmediata)")

elif Paciente_2["temperatura"] >= 39 and Paciente_2["frecuencia_cardiaca"] > 100:
   print("Paciente:", "Paciente_2","Prioridad Naranja (Urgente)")

elif Paciente_2["edad"] < 12 or Paciente_2["edad"] > 65:
   print("Paciente:", "Paciente_2","Prioridad Amarilla (Estandar)")

else:
   print("Paciente:", "Paciente_2","Prioridad Verde (No urgente)")

#Protocolo de aislamiento Paciente 2
if Paciente_2["tiene_sintomas_infecciosos"] and not Paciente_2["esta_vacunado"]:
    destino = "Box de Aislamiento"
else:
    destino = "Sala de Espera General"
print(destino, "\n")


#Paciente 3
if Paciente_3["es_emergencia_critica"] or Paciente_3["temperatura"] > 41:
   print("Prioridad Roja (Inmediata)")

elif Paciente_3["temperatura"] >= 39 and Paciente_3["frecuencia_cardiaca"] > 100:
   print("Paciente:", "Paciente_3","Prioridad Naranja (Urgente)")

elif Paciente_3["edad"] < 12 or Paciente_3["edad"] > 65:
   print("Paciente:", "Paciente_3","Prioridad Amarilla (Estandar)")

else:
   print("Paciente:", "Paciente_3","Prioridad Verde (No urgente)")

#Protocolo de aislamiento Paciente 3
if Paciente_3["tiene_sintomas_infecciosos"] and not Paciente_3["esta_vacunado"]:
    destino = "Box de Aislamiento"
else:
    destino = "Sala de Espera General"
print(destino, "\n")

#Paciente 4
if Paciente_4["es_emergencia_critica"] or Paciente_4["temperatura"] > 41:
   print("Prioridad Roja (Inmediata)")

elif Paciente_4["temperatura"] >= 39 and Paciente_4["frecuencia_cardiaca"] > 100:
   print("Paciente:", "Paciente_4","Prioridad Naranja (Urgente)")

elif Paciente_4["edad"] < 12 or Paciente_4["edad"] > 65:
   print("Paciente:", "Paciente_4","Prioridad Amarilla (Estandar)")

else:
   print("Paciente:", "Paciente_4","Prioridad Verde (No urgente)")

#Protocolo de aislamiento Paciente 4
if Paciente_4["tiene_sintomas_infecciosos"] and not Paciente_4["esta_vacunado"]:
    destino = "Box de Aislamiento"
else:
    destino = "Sala de Espera General"
print(destino, "\n")
# Out:
# Paciente: Paciente_1 Prioridad Roja (Inmediata)
# Sala de Espera General
#
# Paciente: Paciente_2 Prioridad Naranja (Urgente)
# Sala de Espera General
#
# Paciente: Paciente_3 Prioridad Amarilla (Estandar)
# Box de Aislamiento
#
# Paciente: Paciente_4 Prioridad Verde (No urgente)
# Sala de Espera General
